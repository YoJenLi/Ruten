# %%
import requests, time
from bs4 import BeautifulSoup

headers={
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36',
}

res = requests.get('http://www.ruten.com.tw/',headers=headers)
soup = BeautifulSoup(res.text, "lxml")
tlinklist=[]

for i in soup.select('.category-heading-content .sub-category-menu-item'): 
    tlink = i.select('.sub-category-link')[0]['href'].split('?')[-1].split('c=')[-1]
    tlinklist.append('http://class.ruten.com.tw/category/sub00.php?c='+tlink+'$p=')
print(len(tlinklist))
print(tlinklist)
# Out:
# 459
# ...

# %%
for i in range(0,458):
    print(tlinklist[i])
# Out:
# http://class.ruten.com.tw/category/sub00.php?c=00110002$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110020$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110013$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110001$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110003$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110004$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110006$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110014$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110005$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110016$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110009$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110022$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110007$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110018$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110021$p=
# http://class.ruten.com.tw/category/sub00.php?c=00110023$p=
# ...
